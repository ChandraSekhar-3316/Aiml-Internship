# %% [markdown]
# EDA FOR YOUTUBE VIDEO IN 2020 AUGUST

# %% [markdown]
# Structural Diagnosis: Did you use .info(), .describe(), and .shape to evaluate the starting point of your data before making any changes?

# %%
import pandas as pd
import matplotlib.pyplot as plt
yt_dataset = pd.read_csv("2020-Augustvideos.csv")

df = pd.DataFrame(yt_dataset)


# structural diagnosis
print(df.shape)
df.info()
df.describe()
# Out:
# (200, 5)
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          200 non-null    str
#  1   view_count     200 non-null    int64
#  2   likes          200 non-null    int64
#  3   dislikes       200 non-null    int64
#  4   comment_count  200 non-null    int64
# dtypes: int64(4), str(1)
# memory usage: 7.9 KB
#          view_count         likes      dislikes  comment_count
# count  2.000000e+02  2.000000e+02  2.000000e+02   2.000000e+02
# mean   3.040573e+06  1.782171e+05  6.873911e+04   4.594000e+04
# std    1.096807e+07  8.340954e+05  8.724531e+05   3.575211e+05
# min    2.400400e+04  1.230000e+02  1.300000e+01   3.000000e+00
# 25%    4.238065e+05  1.108325e+04  5.585000e+02   5.517500e+02
# 50%    8.523690e+05  3.353550e+04  1.313500e+03   2.136500e+03
# 75%    2.071051e+06  7.536275e+04  3.648000e+03   6.104500e+03
# max    1.247566e+08  9.846002e+06  1.233842e+07   4.823536e+06

# %% [markdown]
# Duplicate Management: Did you isolate, count, and drop duplicate rows before calculating summary statistics, and verify the final duplicate count is exactly zero?

# %% [markdown]
# justification - since my dataset has not any missing values

# %%
null_values = df.isnull().sum()
print(null_values)
# Out:
# title            0
# view_count       0
# likes            0
# dislikes         0
# comment_count    0
# dtype: int64

# %% [markdown]
# Structural

# %% [markdown]
# 1. What are the Top 10 Most Viewed Videos? barh plot

# %%
top_views = df.sort_values(
    by='view_count',
    ascending=False,
)[['title', 'view_count']].head(10)

plt.barh(top_views['title'],top_views['view_count'])
plt.title("top views videos")
plt.xlabel('views')
plt.ylabel('title of the video')
plt.show()
# Out:
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48169 (\N{HANGUL SYLLABLE BANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 53444 (\N{HANGUL SYLLABLE TAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# 2. What are the Top 10 Most Liked Videos? barh plot.

# %%
top_likes = df.sort_values(
    by='likes',
    ascending=False,
)[['title', 'likes']].head(10)

plt.barh(top_likes['title'],top_likes['likes'])
plt.title("top 10 liked videos")
# Out:
# Text(0.5, 1.0, 'top 10 liked videos')
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 48169 (\N{HANGUL SYLLABLE BANG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 53444 (\N{HANGUL SYLLABLE TAN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)

# %% [markdown]
# 3. Which Videos Received the Most Comments? barh plot.

# %%
top_comments = df.sort_values(
    by = "comment_count",
    ascending=False
)[['title','comment_count']].head(10)

plt.barh(top_comments['title'],top_comments['comment_count'])
# Out:
# <BarContainer object of 10 artists>
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 3346 (\N{MALAYALAM LETTER O}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Matplotlib currently does not support Malayalam natively.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 3376 (\N{MALAYALAM LETTER RA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 3393 (\N{MALAYALAM VOWEL SIGN U}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 3370 (\N{MALAYALAM LETTER PA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 3364 (\N{MALAYALAM LETTER TA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 3405 (\N{MALAYALAM SIGN VIRAMA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 3451 (\N{MALAYALAM LETTER CHILLU N}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 3372 (\N{MALAYALAM LETTER BA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 3400 (\N{MALAYALAM VOWEL SIGN AI}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 3349 (\N{MALAYALAM LETTER KA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 3368 (\N{MALAYALAM LETTER NA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 3391 (\N{MALAYALAM VOWEL SIGN I}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 3353 (\N{MALAYALAM LETTER NGA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 3454 (\N{MALAYALAM LETTER CHILLU LL}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 3384 (\N{MALAYALAM LETTER SA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 3374 (\N{MALAYALAM LETTER MA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 3390 (\N{MALAYALAM VOWEL SIGN AA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 3375 (\N{MALAYALAM LETTER YA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3346 (\N{MALAYALAM LETTER O}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Matplotlib currently does not support Malayalam natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3376 (\N{MALAYALAM LETTER RA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3393 (\N{MALAYALAM VOWEL SIGN U}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3370 (\N{MALAYALAM LETTER PA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3364 (\N{MALAYALAM LETTER TA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3405 (\N{MALAYALAM SIGN VIRAMA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3451 (\N{MALAYALAM LETTER CHILLU N}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3372 (\N{MALAYALAM LETTER BA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3400 (\N{MALAYALAM VOWEL SIGN AI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3349 (\N{MALAYALAM LETTER KA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3368 (\N{MALAYALAM LETTER NA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3391 (\N{MALAYALAM VOWEL SIGN I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3353 (\N{MALAYALAM LETTER NGA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3454 (\N{MALAYALAM LETTER CHILLU LL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3384 (\N{MALAYALAM LETTER SA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3374 (\N{MALAYALAM LETTER MA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3390 (\N{MALAYALAM VOWEL SIGN AA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3375 (\N{MALAYALAM LETTER YA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# 4. Which Videos Received the Most Dislikes? barh plot

# %%
most_dislikes = df.sort_values(
    by = "dislikes",
    ascending=False
)[['title','dislikes']].head(10)

plt.barh(most_dislikes['title'],most_dislikes['dislikes'])
# Out:
# <BarContainer object of 10 artists>
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 2327 (\N{DEVANAGARI LETTER GA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Matplotlib currently does not support Devanagari natively.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 2366 (\N{DEVANAGARI VOWEL SIGN AA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 2337 (\N{DEVANAGARI LETTER DDA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 2368 (\N{DEVANAGARI VOWEL SIGN II}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 2325 (\N{DEVANAGARI LETTER KA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 2379 (\N{DEVANAGARI VOWEL SIGN O}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 2346 (\N{DEVANAGARI LETTER PA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 2344 (\N{DEVANAGARI LETTER NA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 2350 (\N{DEVANAGARI LETTER MA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 2375 (\N{DEVANAGARI VOWEL SIGN E}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 2306 (\N{DEVANAGARI SIGN ANUSVARA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 2349 (\N{DEVANAGARI LETTER BHA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 2340 (\N{DEVANAGARI LETTER TA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 2369 (\N{DEVANAGARI VOWEL SIGN U}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 2348 (\N{DEVANAGARI LETTER BA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2327 (\N{DEVANAGARI LETTER GA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Matplotlib currently does not support Devanagari natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2366 (\N{DEVANAGARI VOWEL SIGN AA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2337 (\N{DEVANAGARI LETTER DDA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2368 (\N{DEVANAGARI VOWEL SIGN II}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2325 (\N{DEVANAGARI LETTER KA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2379 (\N{DEVANAGARI VOWEL SIGN O}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2346 (\N{DEVANAGARI LETTER PA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2344 (\N{DEVANAGARI LETTER NA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2350 (\N{DEVANAGARI LETTER MA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2375 (\N{DEVANAGARI VOWEL SIGN E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2306 (\N{DEVANAGARI SIGN ANUSVARA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2349 (\N{DEVANAGARI LETTER BHA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2340 (\N{DEVANAGARI LETTER TA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2369 (\N{DEVANAGARI VOWEL SIGN U}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2348 (\N{DEVANAGARI LETTER BA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# 5. What is the Distribution of Views? histogram plot

# %%
plt.hist(df['view_count'], bins=20)

plt.title("Distribution of Views")
plt.xlabel("Views")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# 6. Is There a Relationship Between Views and Likes? scatter plot.

# %%
import seaborn as sns

sns.scatterplot(
    data = df,
    x='view_count',
    y = 'likes',
)

plt.xlabel('views')
plt.ylabel('likes')
plt.show()

# Doing videos with more views generally receive more likes.

# %% [markdown]
# 10. Which Videos Have the Highest Engagement? barh plot

# %%
#create an engagement 
df['engagement'] = (
    df['likes']/df['view_count']*100 + df['comment_count']/df['view_count']*100
)

#create a top dataset
top_engagement = df.sort_values(
    by='engagement',
    ascending=False
)[['title','engagement']].head(10)

plt.barh(top_engagement['title'],top_engagement['engagement'])
plt.xlabel('engagement')
plt.ylabel('title')
plt.show()
# Out:
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3346 (\N{MALAYALAM LETTER O}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Matplotlib currently does not support Malayalam natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3376 (\N{MALAYALAM LETTER RA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3393 (\N{MALAYALAM VOWEL SIGN U}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3370 (\N{MALAYALAM LETTER PA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3364 (\N{MALAYALAM LETTER TA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3405 (\N{MALAYALAM SIGN VIRAMA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3451 (\N{MALAYALAM LETTER CHILLU N}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3372 (\N{MALAYALAM LETTER BA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3400 (\N{MALAYALAM VOWEL SIGN AI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3349 (\N{MALAYALAM LETTER KA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3368 (\N{MALAYALAM LETTER NA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3391 (\N{MALAYALAM VOWEL SIGN I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3353 (\N{MALAYALAM LETTER NGA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3454 (\N{MALAYALAM LETTER CHILLU LL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3384 (\N{MALAYALAM LETTER SA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3374 (\N{MALAYALAM LETTER MA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3390 (\N{MALAYALAM VOWEL SIGN AA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3375 (\N{MALAYALAM LETTER YA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2348 (\N{DEVANAGARI LETTER BA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Matplotlib currently does not support Devanagari natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2366 (\N{DEVANAGARI VOWEL SIGN AA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2346 (\N{DEVANAGARI LETTER PA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2370 (\N{DEVANAGARI VOWEL SIGN UU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2358 (\N{DEVANAGARI LETTER SHA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2352 (\N{DEVANAGARI LETTER RA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2368 (\N{DEVANAGARI VOWEL SIGN II}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2331 (\N{DEVANAGARI LETTER CHA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2379 (\N{DEVANAGARI VOWEL SIGN O}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2309 (\N{DEVANAGARI LETTER A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2310 (\N{DEVANAGARI LETTER AA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2351 (\N{DEVANAGARI LETTER YA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2375 (\N{DEVANAGARI VOWEL SIGN E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2327 (\N{DEVANAGARI LETTER GA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2350 (\N{DEVANAGARI LETTER MA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2332 (\N{DEVANAGARI LETTER JA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\AIML\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2364 (\N{DEVANAGARI SIGN NUKTA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Box Plot
sns.boxplot(data=df[['view_count','likes','comment_count']])
plt.show()

# %%
# Correlation Heatmap
import seaborn as sns

plt.figure(figsize=(8,6))
sns.heatmap(df[['view_count','likes','dislikes','comment_count']].corr(),
            annot=True,
            cmap='coolwarm')

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Insights for ML Modeling

# %% [markdown]
# Outliers

# %% [markdown]
# The dataset contains several outliers in the view_count, likes, dislikes, and comment_count columns. These outliers represent highly viral videos that received exceptionally high engagement compared to other videos. Since these values reflect genuine user behavior and popularity rather than data errors, they were retained. For machine learning models, transformations such as logarithmic scaling can be applied to reduce the impact of extreme values

# %% [markdown]
# Collinearity

# %% [markdown]
# There is a strong positive relationship between view_count, likes, and comment_count. Videos with higher view counts generally receive more likes and comments. This indicates potential multicollinearity among engagement-related features. Before model training, feature selection or dimensionality reduction techniques may be considered to reduce redundancy.

# %% [markdown]
# Feature Importance

# %% [markdown]
# The engagement metrics (likes, comments, and views) appear to be the most informative features in the dataset. These variables capture audience interaction and can be useful predictors when estimating video popularity or engagement levels.

# %% [markdown]
# Data Distribution

# %% [markdown]
# Most engagement-related features are highly right-skewed. A small number of videos achieve extremely high popularity, while the majority receive moderate engagement. Feature scaling and transformation techniques may improve model performance.

# %% [markdown]
# Modelling consderations

# %% [markdown]
# The dataset is clean and contains no missing values.
# No duplicate records were found.
# Outliers should be retained because they represent real viral content.
# Highly correlated features should be evaluated before model training.
# Log transformation and feature scaling may improve prediction accuracy.
# The dataset can be used to predict video popularity, engagement, or future view counts.

# %% [markdown]
# Conclusion

# %% [markdown]
# The dataset contains meaningful engagement signals and is suitable for machine learning tasks such as popularity prediction, engagement forecasting, and trend analysis. Proper handling of skewed distributions and correlated features can help improve model performance and interpretability
